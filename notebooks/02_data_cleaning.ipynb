# %% [markdown]
# # Notebook 02: Data Cleaning
# Cleaning, deduplication, handling missing values.
#
# **Output:** `data/preprocessed/diabetic_preprocessed.csv`

# %%
import os
import sys
if os.path.basename(os.getcwd()) == 'notebooks':
    os.chdir('..')
sys.path.insert(0, '.')

from src.python_pipeline.data_cleaning import run_cleaning_pipeline

df_cleaned = run_cleaning_pipeline(
    data_path='data/raw/diabetic_data.csv',
    ids_path='data/raw/IDS_mapping.csv',
    output_path='data/preprocessed/diabetic_preprocessed.csv'
)
print(f'Cleaned Shape: {df_cleaned.shape}')
