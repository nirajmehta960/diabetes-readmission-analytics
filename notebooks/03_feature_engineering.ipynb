# %% [markdown]
# # Notebook 03: Feature Engineering
# New features, encoding, transformations.
#
# **Input:** `data/preprocessed/diabetic_preprocessed.csv`
# **Output:** `data/featured/diabetic_featured.csv` and `data/featured/model_ready.csv`

# %%
import pandas as pd
import os
import sys

if os.path.basename(os.getcwd()) == 'notebooks':
    os.chdir('..')
sys.path.insert(0, '.')

from src.feature_engineering import run_feature_engineering_pipeline

df = pd.read_csv('data/preprocessed/diabetic_preprocessed.csv')
print(f'Preprocessed data: {df.shape}')

# %%
df_featured, df_model_ready = run_feature_engineering_pipeline(df)
print(f'Featured shape: {df_featured.shape}')
print(f'Model-ready shape: {df_model_ready.shape}')
