# %% [markdown]
# # Notebook 04: Exploratory Data Analysis
# Exploratory analysis and visualizations.

# %%
import pandas as pd
import os
import sys

if os.path.basename(os.getcwd()) == 'notebooks':
    os.chdir('..')
sys.path.insert(0, '.')

from src.python_pipeline.visualizations import generate_all_eda_charts

# Load preprocessed data (or featured for specific fields)
df = pd.read_csv('data/featured/diabetic_featured.csv')
df.head()
# Out:
#               race  gender      age  admission_type_id  \
# 0        Caucasian    Male  [60-70)                  2
# 1        Caucasian  Female  [80-90)                  1
# 2  AfricanAmerican    Male  [80-90)                  2
# 3        Caucasian  Female  [20-30)                  1
# 4        Caucasian    Male  [80-90)                  6
#
#    discharge_disposition_id  admission_source_id  time_in_hospital  \
# 0                         1                    1                14
# 1                         3                    7                14
# 2                         6                    1                14
# 3                         3                    5                14
# 4                        22                   17                14
#
#         medical_specialty  num_lab_procedures  num_procedures  ...  \
# 0                 Unknown                  59               5  ...
# 1  Family/GeneralPractice                  67               0  ...
# ...

# %% [markdown]
# ### Generate All EDA Charts

# %%
generate_all_eda_charts(df, save_dir='images/eda_charts')
# Out:
# /Users/nirajmehta/Documents/Data Analyst Projects/diabetes-readmission-analytics/./src/visualizations.py:87: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, x='readmit_30', ax=ax, palette='Set2')
# /Users/nirajmehta/Documents/Data Analyst Projects/diabetes-readmission-analytics/./src/visualizations.py:104: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=df, x='age', y='readmit_30', errorbar=None, palette='viridis', ax=ax)
# /Users/nirajmehta/Documents/Data Analyst Projects/diabetes-readmission-analytics/./src/visualizations.py:114: FutureWarning:
#
# ...
